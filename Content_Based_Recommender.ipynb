# %% [markdown]
# # MCSD 6227 Master Project 2
#
# Name: Tan Boon Chu
#
# Matrics No.: MCS211006
#
# Project: EDA and Recommender System for Steam Online Gaming Platform

# %% [markdown]
# ## Data Import and Checking

# %%
# Import PyDrive and associated libraries
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Other libraries
import pandas as pd
import numpy as np

# Authenticate and create the PyDrive client
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# Download a file based on its file ID.
file_id = '1SdwjxbJ6GG4V2P6OiUzUEJRIYDpRsxYE'
downloaded = drive.CreateFile({'id': file_id})

# Save file in Colab memory
downloaded.GetContentFile('steam_clean_data.csv')

# %%
# Read Data file
df = pd.read_csv('steam_clean_data.csv')
df = pd.DataFrame(df)

# print out number of rows and columns
print('Rows:', df.shape[0])
print('Columns:', df.shape[1])

# View first 5 rows
df.head()
# Out:
# Rows: 28375
# Columns: 16
#    appid                       name         developer  positive  negative  \
# 0      1             Counter-Strike             Valve    124534      3339
# 1      2      Team Fortress Classic             Valve      3318       633
# 2      3              Day of Defeat             Valve      3416       398
# 3      4         Deathmatch Classic             Valve      1273       267
# 4      5  Half-Life: Opposing Force  Gearbox Software      5250       288
#
#                      owners  average_playtime  median_playtime  price  \
# 0  10,000,000 .. 20,000,000           17612.0            317.0   9.99
# 1   5,000,000 .. 10,000,000             277.0             62.0   4.99
# 2   5,000,000 .. 10,000,000             187.0             34.0   4.99
# 3   5,000,000 .. 10,000,000             258.0            184.0   4.99
# 4   5,000,000 .. 10,000,000             624.0            415.0   4.99
#
#                                            languages   genre  \
# 0  English, French, German, Italian, Spanish - Sp...  Action
# 1  English, French, German, Italian, Spanish - Sp...  Action
# 2  English, French, German, Italian, Spanish - Spain  Action
# 3  English, French, German, Italian, Spanish - Sp...  Action
# 4                    English, French, German, Korean  Action
#
#                                 detailed_description  Ratings Is_Free English  \
# 0  Play the world's number 1 online action game. ...   121195    Paid     Yes
# 1  One of the most popular online action games of...     2685    Paid     Yes
# 2  Enlist in an intense brand of Axis vs. Allied ...     3018    Paid     Yes
# 3  Enjoy fast-paced multiplayer gaming with Death...     1006    Paid     Yes
# 4  Return to the Black Mesa Research Facility as ...     4962    Paid     Yes
#
#    download
# 0  20000000
# 1  10000000
# 2  10000000
# 3  10000000
# 4  10000000

# %%
df.dtypes
# Out:
# appid                     int64
# name                     object
# developer                object
# positive                  int64
# negative                  int64
# owners                   object
# average_playtime        float64
# median_playtime         float64
# price                   float64
# languages                object
# genre                    object
# detailed_description     object
# Ratings                   int64
# Is_Free                  object
# English                  object
# download                  int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# appid                   0
# name                    0
# developer               0
# positive                0
# negative                0
# owners                  0
# average_playtime        0
# median_playtime         0
# price                   0
# languages               0
# genre                   0
# detailed_description    0
# Ratings                 0
# Is_Free                 0
# English                 0
# download                0
# dtype: int64

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [appid, name, developer, positive, negative, owners, average_playtime, median_playtime, price, languages, genre, detailed_description, Ratings, Is_Free, English, download]
# Index: []

# %%
df.describe()
# Out:
#                appid      positive       negative  average_playtime  \
# count   28375.000000  2.837500e+04   28375.000000      28375.000000
# mean    60143.055189  8.748495e+02     186.707419        137.472634
# std     24772.753533  1.831796e+04    4153.111135       1780.315617
# min         1.000000  0.000000e+00       0.000000          0.000000
# 25%     40698.500000  6.000000e+00       2.000000          0.000000
# 50%     60433.000000  2.200000e+01       8.000000          0.000000
# 75%     80137.000000  1.130000e+02      38.000000          0.000000
# max    106946.000000  2.644404e+06  487076.000000     190625.000000
#
#        median_playtime         price       Ratings      download
# count     28375.000000  28375.000000  2.837500e+04  2.837500e+04
# mean        135.571736      7.652513  6.881421e+02  1.714122e+05
# std        2299.763575     11.255978  1.538953e+04  1.733554e+06
# min           0.000000      0.000000 -7.738000e+03  2.000000e+04
# 25%           0.000000      1.990000  1.000000e+00  2.000000e+04
# 50%           0.000000      4.990000  1.100000e+01  2.000000e+04
# 75%           0.000000      9.990000  6.400000e+01  5.000000e+04
# max      190625.000000    595.990000  2.242091e+06  2.000000e+08

# %% [markdown]
# Reduce the size of dataset due to hardware limitation

# %%
df1 = sorted(df.download, reverse=True)

# %%
# number of download at 5000th row
df1[15000]
# Out:
# 50000

# %% [markdown]
# Backup Data

# %%
df2 = df

# %%
df = df.loc[(df['download'] >= 50000)].copy()

# %%
df.reset_index(inplace=True)

# %%
print('Rows:', df.shape[0])
print('Columns:', df.shape[1])
df.head()
# Out:
# Rows: 8524
# Columns: 17
#    index  appid                       name         developer  positive  \
# 0      0      1             Counter-Strike             Valve    124534
# 1      1      2      Team Fortress Classic             Valve      3318
# 2      2      3              Day of Defeat             Valve      3416
# 3      3      4         Deathmatch Classic             Valve      1273
# 4      4      5  Half-Life: Opposing Force  Gearbox Software      5250
#
#    negative                    owners  average_playtime  median_playtime  \
# 0      3339  10,000,000 .. 20,000,000           17612.0            317.0
# 1       633   5,000,000 .. 10,000,000             277.0             62.0
# 2       398   5,000,000 .. 10,000,000             187.0             34.0
# 3       267   5,000,000 .. 10,000,000             258.0            184.0
# 4       288   5,000,000 .. 10,000,000             624.0            415.0
#
#    price                                          languages   genre  \
# 0   9.99  English, French, German, Italian, Spanish - Sp...  Action
# 1   4.99  English, French, German, Italian, Spanish - Sp...  Action
# 2   4.99  English, French, German, Italian, Spanish - Spain  Action
# 3   4.99  English, French, German, Italian, Spanish - Sp...  Action
# 4   4.99                    English, French, German, Korean  Action
#
#                                 detailed_description  Ratings Is_Free English  \
# 0  Play the world's number 1 online action game. ...   121195    Paid     Yes
# 1  One of the most popular online action games of...     2685    Paid     Yes
# 2  Enlist in an intense brand of Axis vs. Allied ...     3018    Paid     Yes
# 3  Enjoy fast-paced multiplayer gaming with Death...     1006    Paid     Yes
# 4  Return to the Black Mesa Research Facility as ...     4962    Paid     Yes
#
#    download
# 0  20000000
# 1  10000000
# 2  10000000
# 3  10000000
# 4  10000000

# %%
df.drop(columns=['index', 'appid'], inplace= True)

# %% [markdown]
# Backup Data

# %%
df3 = df

# %% [markdown]
# ## TF-IDF Text Vectorization and Transformation

# %% [markdown]
# Text cleaning

# %%
df['detailed_description'] = [i.replace('\n', ' ') for i in df['detailed_description']]

# %%
# Remove html tags, new line, and carriage return in description
import re
def remove_tag(html_text):
  re_html = re.compile(r'<[^>]+>|\r|\n|\t|http\S+')
  return re_html.sub(' ',html_text)

# %%
df['detailed_description'] = df['detailed_description'].apply(remove_tag)

# %%
df['detailed_description'] = [i.replace("'", '') for i in df['detailed_description']]

# %%
df['detailed_description'] = [i.replace(",", '') for i in df['detailed_description']]

# %%
import string 
df['detailed_description'] = [i.lower().translate(str.maketrans(string.punctuation, ' '*len(string.punctuation))) for i in df['detailed_description']]

# %%
df['detailed_description'] = [i.replace("—", ' ') for i in df['detailed_description']]

# %%
df.detailed_description
# Out:
# 0       play the worlds number 1 online action game  e...
# 1       one of the most popular online action games of...
# 2       enlist in an intense brand of axis vs  allied ...
# 3       enjoy fast paced multiplayer gaming with death...
# 4       return to the black mesa research facility as ...
#                               ...
# 8519    blockade classic       the game which has beco...
# 8520       choose your hero  begin your journey with  ...
# 8521      waking up naked in a grotesque slaughterhous...
# 8522        killstreak tv  is a fast paced free for al...
# 8523     support us        about the game    sin slaye...
# Name: detailed_description, Length: 8524, dtype: object

# %%
df['detailed_description'].iloc[8519]
# Out:
# 'blockade classic       the game which has become a legend for millions of players is back  dynamic cubic world with the ability to change the environment  in the arsenal you will find many prototypes of modern weapons which will give you unlimited possibilities for choosing the methods of destroying the enemy  a large number of cool game modes in which you can shoot destroy build your own base be the last of the survivors in front of a horde of zombies  upgrade your weapon customize your character increase your in game level prove your superiority by entering your name in the top 100 rating of players from around the world  in this game everyone can find something to their liking  a huge variety of maps created for you by the developers as well as the community  in some game modes on one battlefield up to 4 teams can participate simultaneously  clan battles in which there is only one goal   to become a champion '

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
w_tokenizer = nltk.tokenize.WhitespaceTokenizer()

# %%
def lemmatize_text(text):
    return [lemmatizer.lemmatize(word, 'v') for word in w_tokenizer.tokenize(text)]

# %%
df['detailed_description'] = df['detailed_description'].apply(lemmatize_text)

# %%
df['detailed_description']
# Out:
# 0       [play, the, worlds, number, 1, online, action,...
# 1       [one, of, the, most, popular, online, action, ...
# 2       [enlist, in, an, intense, brand, of, axis, vs,...
# 3       [enjoy, fast, pace, multiplayer, game, with, d...
# 4       [return, to, the, black, mesa, research, facil...
#                               ...
# 8519    [blockade, classic, the, game, which, have, be...
# 8520    [choose, your, hero, begin, your, journey, wit...
# 8521    [wake, up, naked, in, a, grotesque, slaughterh...
# 8522    [killstreak, tv, be, a, fast, pace, free, for,...
# 8523    [support, us, about, the, game, sin, slayers, ...
# Name: detailed_description, Length: 8524, dtype: object

# %%
df.detailed_description = df.detailed_description.str.join(' ')

# %%
#Import TfIdfVectorizer from scikit-learn
from sklearn.feature_extraction.text import TfidfVectorizer

#Define a TF-IDF Vectorizer Object. Remove all english stop words such as 'the', 'a'
tfidf = TfidfVectorizer(stop_words='english')

#Construct the required TF-IDF matrix by fitting and transforming the data
tfidf_matrix = tfidf.fit_transform(df['detailed_description'])

#Output the shape of tfidf_matrix
tfidf_matrix.shape
# Out:
# (8524, 47353)

# %% [markdown]
# calculating the dot product will directly give us the cosine similarity score. Therefore, sklearn's linear_kernel() instead of cosine_similarities() since it is faster.

# %%
# Import linear_kernel
from sklearn.metrics.pairwise import linear_kernel

# Compute the cosine similarity matrix
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
#Construct a reverse map of indices and game titles
indices = pd.Series(df.index, index=df['name'])

# %% [markdown]
# Genre-Based

# %%
df['feature'] = df['genre'] + ' ' + df ['name'] + ' ' + df['developer']

# %%
df['feature'] = [i.lower().translate(str.maketrans('', '', string.punctuation)) for i in df['feature']]

# %%
df['feature'] = [i.lower().translate(str.maketrans('', '', string.punctuation)) for i in df['feature']]

# %%
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(df['feature'])

# %%
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim2 = cosine_similarity(count_matrix, count_matrix)

# %% [markdown]
# ## Cosine Similarities

# %%
# Cosine Similarities Function
def get_recommendations(name, cosine_sim=cosine_sim):
    # index of the game 
    idx = indices[name]
    
    # similarity scores 
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    # Sort based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar game
    sim_scores = sim_scores[1:11]
    print(sim_scores)
    # Get the recommended game indices
    game_indices = [i[0] for i in sim_scores]
    
    # Return the top 10 most similar games
    return df.loc[game_indices]

# %%
get_recommendations('Dota 2')
# Out:
# [(1673, 0.22455487926581133), (7567, 0.20045314253959892), (5959, 0.19935081446334316), (712, 0.18671824928610312), (5383, 0.1860029256709196), (6307, 0.18295835520302983), (2004, 0.18082353297510473), (4405, 0.18053668907755824), (5989, 0.17964060565772252), (4032, 0.1753513169294072)]
#                                   name            developer  positive  \
# 1673  Heroes of Havoc: Idle Adventures          Kiz Studios        76
# 7567             Heroes of Hammerwatch           Crackshell      1401
# 5959                       Shop Heroes      Cloudcade, Inc.      1978
# 712     Might & Magic: Clash of Heroes       Capybara Games      1293
# 5383                            Guards  Battlecruiser Games       333
# 6307                    Heroes Evolved           Net Dragon       351
# 2004                      Lost Saga NA     IO Entertainment       415
# 4405                        Battleborn     Gearbox Software      5692
# 5989                       Flat Heroes     Parallel Circles       282
# 4032                        Tap Heroes              VaragtP       887
#
#       negative                owners  average_playtime  median_playtime  \
# 1673       114     50,000 .. 100,000               0.0              0.0
# 7567       356    100,000 .. 200,000              45.0             45.0
# 5959       868  500,000 .. 1,000,000            1543.0           2207.0
# 712        157    200,000 .. 500,000            1595.0           1595.0
# 5383        39      20,000 .. 50,000               0.0              0.0
# 6307       294    100,000 .. 200,000            2021.0           2021.0
# 2004       281    200,000 .. 500,000              27.0             53.0
# 4405      3494  500,000 .. 1,000,000             652.0            752.0
# 5989        28      20,000 .. 50,000               0.0              0.0
# 4032       294    200,000 .. 500,000             270.0            220.0
#
#       price                                          languages  \
# 1673   0.00  English, French, Italian, German, Spanish - Sp...
# 7567  11.99   English, Simplified Chinese, Traditional Chinese
# 5959   0.00  English, French, Italian, German, Spanish - Sp...
# 712    9.99  English, French, German, Italian, Spanish - Sp...
# 5383   4.99                           English, German, Russian
# 6307   0.00                   English, French, German, Russian
# 2004   0.00                                            English
# 4405   0.00  English, French, Italian, German, Spanish - Sp...
# 5989   7.99  English, French, Italian, German, Spanish - Sp...
# 4032   0.74                                            English
#
#                                                   genre  \
# 1673                                  Free to Play, RPG
# 7567                                 Action, Indie, RPG
# 5959  Casual, Free to Play, Massively Multiplayer, R...
# 712                                       RPG, Strategy
# 5383                         Adventure, Indie, Strategy
# 6307  Action, Casual, Free to Play, Massively Multip...
# 2004                       Action, Casual, Free to Play
# 4405                                             Action
# 5989                                      Action, Indie
# 4032              Action, Adventure, Casual, Indie, RPG
#
#                                    detailed_description  Ratings Is_Free  \
# 1673  victory be only a tap away now be your time… g...      -38    Free
# 7567  heroes of hammerwatch be a rogue lite action a...     1045    Paid
# 5959  craft legendary items gear up your heroes for ...     1110    Free
# 712   might amp magic clash of heroes take place 40 ...     1136    Paid
# 5383  play by the 4 heroes team defend against the h...      294    Paid
# 6307  feature update about the game whats heroes evo...       57    Free
# 2004  part fighter part brawler and make from pure a...      134    Free
# 4405  play for free now the battleborn free trial gr...     2198    Free
# 5989  when be the last time you felt like a hero fla...      254    Paid
# 4032  welcome to the first puppet show rpg battle to...      593    Paid
#
#      English  download                                            feature
# 1673     Yes    100000  free to play rpg heroes of havoc idle adventur...
# 7567     Yes    200000  action indie rpg heroes of hammerwatch crackshell
# 5959     Yes   1000000  casual free to play massively multiplayer rpg ...
# 712      Yes    500000  rpg strategy might  magic clash of heroes capy...
# 5383     Yes     50000  adventure indie strategy guards battlecruiser ...
# 6307     Yes    200000  action casual free to play massively multiplay...
# 2004     Yes    500000  action casual free to play lost saga na io ent...
# 4405     Yes   1000000                 action battleborn gearbox software
# 5989     Yes     50000          action indie flat heroes parallel circles
# 4032     Yes    500000  action adventure casual indie rpg tap heroes v...

# %%
df['detailed_description'].iloc[5383]
# Out:
# 'play by the 4 heroes team defend against the hordes of monsters plan your move improve your abilities defeat all the enemies on each level and join the deadly fight with boss feature an original turn base battle system eight heroes with unique abilities and battle techique а lot of additional skills a variety of magical items an unlimited choice of game tactics additional difficulty level which will become a real challenge even for the most experience strategist gameplay the main feature of the game be a unique turn base battle system you command the team of 4 heroes 3 of which be fight on the front line while the 4th be recover health behind the back of his team mat to make a move you need to change position of any two heroes if the hero move from the back line to the front he use superattack for example the knight be thrill the land stun all the enemies on the line while the huntress be charge a bow with energy simultaneously fire arrows in all the enemies'

# %%
get_recommendations('Counter-Strike: Global Offensive').head(2)
# Out:
# [(4134, 0.26113337191536884), (8154, 0.2035696442423604), (10, 0.19683762364225035), (7, 0.18707736517029863), (20, 0.184686304845677), (2134, 0.1819208037360571), (6125, 0.16763178730593334), (7563, 0.16662630914212204), (3585, 0.1638449639849139), (5744, 0.16116501634163977)]
#                                 name      developer  positive  negative  \
# 4134  DARIUSBURST Chronicle Saviours        Pyramid       375        65
# 8154                     Cereal Soup  Wild Arts LLC       218       239
#
#                  owners  average_playtime  median_playtime  price  \
# 4134   20,000 .. 50,000              31.0             31.0  49.99
# 8154  50,000 .. 100,000               0.0              0.0   0.00
#
#                                               languages  \
# 4134  English, Japanese, French, Italian, German, Sp...
# 8154                                            English
#
#                                                   genre  \
# 4134                                             Action
# 8154  Adventure, Free to Play, Massively Multiplayer...
#
#                                    detailed_description  Ratings Is_Free  \
# 4134  warn dariusburst chronicle saviours be approac...      310    Paid
# 8154  cereal soup be an mmo style animal roleplay ga...      -21    Free
#
#      English  download                                            feature
# 4134     Yes     50000      action dariusburst chronicle saviours pyramid
# 8154     Yes    100000  adventure free to play massively multiplayer r...

# %%
get_recommendations('Unturned').head(2)
# Out:
# [(3609, 0.18812175638499976), (6696, 0.16546690218998075), (7809, 0.16291161051122138), (1428, 0.15267046654695063), (6368, 0.1522763210757263), (1677, 0.15109649056612065), (804, 0.15069594163123678), (2044, 0.14841537851072234), (7793, 0.1448926224220944), (7453, 0.14001141954061178)]
#                               name                 developer  positive  \
# 3609            Romero's Aftermath  Free Reign Entertainment      5668
# 6696  Stormworks: Build and Rescue          Sunfire Software      1478
#
#       negative                  owners  average_playtime  median_playtime  \
# 3609      6073  2,000,000 .. 5,000,000             188.0             72.0
# 6696       171       50,000 .. 100,000               0.0              0.0
#
#       price         languages  \
# 3609   0.00  English, Russian
# 6696  19.99           English
#
#                                                   genre  \
# 3609  Violent, Action, Free to Play, Indie, Massivel...
# 6696                           Simulation, Early Access
#
#                                    detailed_description  Ratings Is_Free  \
# 3609  aftermath end of service notice dear players w...     -405    Free
# 6696  join a world where you design create and pilot...     1307    Paid
#
#      English  download                                            feature
# 3609     Yes   5000000  violent action free to play indie massively mu...
# 6696     Yes    100000  simulation early access stormworks build and r...

# %%
get_recommendations("PLAYERUNKNOWN'S BATTLEGROUNDS").head(2)
# Out:
# [(8292, 0.4398307455197657), (8472, 0.391565138723687), (8159, 0.2659653749314947), (7463, 0.25329089424614715), (8386, 0.23176439922435532), (8113, 0.20293823997491447), (5001, 0.1941799481358312), (5091, 0.19326149565592848), (8275, 0.1868330760654841), (8294, 0.18322104518816834)]
#                      name     developer  positive  negative  \
# 8292              PUGNite  OfficialAndy        72        54
# 8472  Pixel Battle Royale    FreezeNova       164       137
#
#                  owners  average_playtime  median_playtime  price languages  \
# 8292   20,000 .. 50,000               0.0              0.0   0.99   English
# 8472  50,000 .. 100,000               0.0              0.0   0.00   English
#
#                                  genre  \
# 8292  Action, Adventure, Casual, Indie
# 8472       Action, Free to Play, Indie
#
#                                    detailed_description  Ratings Is_Free  \
# 8292  the battle royale you all have be wait for pug...       18    Paid
# 8472  pixel battle royale be a fantastic battle roya...       27    Free
#
#      English  download                                            feature
# 8292     Yes     50000  action adventure casual indie pugnite official...
# 8472     Yes    100000  action free to play indie pixel battle royale ...

# %%
get_recommendations('Warframe').head(2)
# Out:
# [(1409, 0.37440097413078105), (1410, 0.19719443977775492), (7897, 0.17502563077259345), (5652, 0.14600484030385308), (5739, 0.14474879265459972), (1277, 0.11865554252111976), (7645, 0.11582325964760253), (2070, 0.1124869584445276), (5234, 0.11140477659361485), (8090, 0.11105270854627719)]
#                         name developer  positive  negative  \
# 1409             Prime World     Nival      1954      1378
# 1410  Prime World: Defenders     Nival       673       213
#
#                     owners  average_playtime  median_playtime  price  \
# 1409  500,000 .. 1,000,000              28.0             33.0   0.00
# 1410    100,000 .. 200,000             739.0            739.0   9.99
#
#                               languages  \
# 1409  Russian, English, German, Turkish
# 1410   English, Russian, French, German
#
#                                                  genre  \
# 1409  Action, Free to Play, Massively Multiplayer, RPG
# 1410                      Casual, Indie, RPG, Strategy
#
#                                    detailed_description  Ratings Is_Free  \
# 1409  prime world be a free online game in rpg moba ...      576    Free
# 1410  the second part of your beloved game available...      460    Paid
#
#      English  download                                            feature
# 1409     Yes   1000000  action free to play massively multiplayer rpg ...
# 1410     Yes    200000  casual indie rpg strategy prime world defender...

# %%
df['detailed_description'].iloc[8292]
# Out:
# 'the battle royale you all have be wait for pugnite be a mini battle royale game where you compete against players your task be to choose one character and start play feature gun items gameplay battle royale'

# %%
df.loc[df['name'] == 'Warframe',['detailed_description']].values[0]
# Out:
# array(['just update band together to save the vallis with abilities power by her shield hildryn be always ready to jump back into the fight take control of her devastate abilities as you work together with the community to solve operation bury debts melee change phase one phase 1 of the much anticipate melee revamp be here with these change you’ll experience more fluid combat and a smoother faster bolder system to harness as you slash your way through the origin system phase 1 include uninterrupted combat with no need for lock into melee mode combo resume aim grind slam and more tenno reinforcements become the deceptively sentient warrior with the illusive limbo limina skin customize your ride with new k drive modular part and give your operator a fresh look with one of three new curly hairstyles prime access get prime access now and make the newest prime yours instantly for prime access bundle options click here prime access be a rotate program that include the latest prime warframes and prime gear in bundle of discount platinum and other exclusive items prime access offer instant access to the latest prime warframes and prime gear without require the build time for more prime access information click here about the game choose your warframe with more than 30 warframes each fully customizable with their own unique abilities you can create the perfect warframe for you assemble your arsenal katanas crossbows flamethrowers expand your arsenal with more than 300 diverse weapons then modify each one to match your playstyle experience fast pace combat slice and dice through hordes of enemies or go in gun blaze or sneak your way in the choice be yours explore open worlds explore discover fight and fly in massive open landscape within warframe fluid parkour movement seamlessly leap slide and glide through capital ship and underground compound with a robust movement system a solar system in ruin in the far future world of warframe grotesque clone and capitalist machine dominate our solar system fight back against greed and corruption as you explore 18 worlds fill with techno organic horrors squad up you don’t have to work alone invite three friends or fight alongside the 38 million strong in our tenno community ninjas play free warframe be entirely free to play with no barrier to entry there’s nothing to stop you and your friends from join our world welcome to the origin system tenno'],
#       dtype=object)

# %% [markdown]
# Genre Based

# %%
def feature_rec(name, cosine_sim=cosine_sim2):
    idx = indices[name]
    
    sim_scores = list(enumerate(cosine_sim2[idx]))
    
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    sim_scores = sim_scores[1:11]
    print(sim_scores)
    game_indices = [i[0] for i in sim_scores]
    
    return df.loc[game_indices]

# %%
feature_rec('Dota 2')
# Out:
# [(19, 0.6666666666666669), (3161, 0.6666666666666669), (3482, 0.6172133998483676), (5254, 0.6123724356957946), (1615, 0.5773502691896258), (2711, 0.5773502691896258), (2912, 0.5773502691896258), (3452, 0.5773502691896258), (4766, 0.5773502691896258), (6694, 0.5773502691896258)]
#                  name        developer  positive  negative  \
# 19    Team Fortress 2            Valve    515879     34036
# 3161         Gigantic      Motiga Inc.      5065      1904
# 3482           CroNix           MAGICS       209       244
# 5254          The Lab            Valve      2926       145
# 1615         Toribash     Nabi Studios     11143      1563
# 2711     Call to Arms  Digitalmindsoft      5787      2144
# 2912             Boid            Mokus       536       132
# 3452   Games of Glory   Lightbulb Crew       328       254
# 4766            CLASH     Ultima Games        87       120
# 6694             Nick  Firstborn Games        40        11
#
#                         owners  average_playtime  median_playtime  price  \
# 19    20,000,000 .. 50,000,000            8495.0            623.0    0.0
# 3161    2,000,000 .. 5,000,000             140.0             50.0    0.0
# 3482        200,000 .. 500,000              15.0             16.0    0.0
# 5254      500,000 .. 1,000,000              95.0            127.0    0.0
# 1615    2,000,000 .. 5,000,000             130.0             42.0    0.0
# 2711      500,000 .. 1,000,000            2550.0            728.0    0.0
# 2912        200,000 .. 500,000               5.0              8.0    0.0
# 3452        200,000 .. 500,000              74.0            109.0    0.0
# 4766        100,000 .. 200,000             226.0            272.0    0.0
# 6694         50,000 .. 100,000               0.0              0.0    0.0
#
#                                               languages  \
# 19    English, Danish, Dutch, Finnish, French, Germa...
# 3161                            English, French, German
# 3482  English, French, Italian, German, Spanish - Sp...
# 5254  English, French, German, Czech, Finnish, Hunga...
# 1615  English, French, Portuguese, Russian, Spanish ...
# 2711  English, French, Italian, German, Spanish - Sp...
# 2912                                 English, Ukrainian
# 3452       English, French, German, Portuguese - Brazil
# 4766                                            English
# 6694                                            English
#
#                                                   genre  \
# 19                                 Action, Free to Play
# 3161                     Action, Free to Play, Strategy
# 3482             Action, Casual, Free to Play, Strategy
# 5254                                       Free to Play
# 1615              Action, Free to Play, Indie, Strategy
# 2711  Action, Free to Play, Indie, Simulation, Strategy
# 2912      Action, Casual, Free to Play, Indie, Strategy
# 3452                     Action, Free to Play, Strategy
# 4766              Action, Free to Play, Indie, Strategy
# 6694              Action, Free to Play, Indie, Strategy
#
#                                    detailed_description  Ratings Is_Free  \
# 19    the jungle inferno update play the all new jun...   481843    Free
# 3161                          new update about the game     3161    Free
# 3482  join the battlefield of a post apocalypse worl...      -35    Free
# 5254  set in a pocket universe of aperture science t...     2781    Free
# 1615  quot just when ragdoll be become an irritant f...     9580    Free
# 2711  just update enjoy the latest and massive updat...     3643    Free
# 2912  boid be real time strategy at its most primal ...      404    Free
# 3452  fight alongside your friends on pc and on ps4 ...       74    Free
# 4766  earth be in the grip of a bitter cold war nucl...      -33    Free
# 6694  time to kick some christmass nick be a free vr...       29    Free
#
#      English  download                                            feature
# 19       Yes  50000000          action free to play team fortress 2 valve
# 3161     Yes   5000000   action free to play strategy gigantic motiga inc
# 3482     Yes    500000  action casual free to play strategy cronix magics
# 5254     Yes   1000000                         free to play the lab valve
# 1615     Yes   5000000  action free to play indie strategy toribash na...
# 2711     Yes   1000000  action free to play indie simulation strategy ...
# 2912     Yes    500000  action casual free to play indie strategy boid...
# 3452     Yes    500000  action free to play strategy games of glory li...
# 4766     Yes    200000  action free to play indie strategy clash ultim...
# 6694     Yes    100000  action free to play indie strategy nick firstb...

# %%
feature_rec('Counter-Strike: Global Offensive').head(2)
# Out:
# [(0, 0.5477225575051663), (19, 0.5163977794943223), (22, 0.5163977794943223), (10, 0.4743416490252569), (5254, 0.4743416490252569), (1115, 0.4472135954999579), (5961, 0.43412157106222965), (7, 0.4242640687119285), (3360, 0.4242640687119285), (8522, 0.4242640687119285)]
#                name developer  positive  negative                    owners  \
# 0    Counter-Strike     Valve    124534      3339  10,000,000 .. 20,000,000
# 19  Team Fortress 2     Valve    515879     34036  20,000,000 .. 50,000,000
#
#     average_playtime  median_playtime  price  \
# 0            17612.0            317.0   9.99
# 19            8495.0            623.0   0.00
#
#                                             languages                 genre  \
# 0   English, French, German, Italian, Spanish - Sp...                Action
# 19  English, Danish, Dutch, Finnish, French, Germa...  Action, Free to Play
#
#                                  detailed_description  Ratings Is_Free  \
# 0   play the worlds number 1 online action game en...   121195    Paid
# 19  the jungle inferno update play the all new jun...   481843    Free
#
#    English  download                                    feature
# 0      Yes  20000000                 action counterstrike valve
# 19     Yes  50000000  action free to play team fortress 2 valve

# %%
feature_rec('Unturned').head(2)
# Out:
# [(5471, 0.7378647873726218), (8129, 0.7378647873726218), (6504, 0.6708203932499369), (8383, 0.632455532033676), (3048, 0.6324555320336759), (3231, 0.6324555320336759), (3555, 0.6324555320336759), (5039, 0.6324555320336759), (6908, 0.6324555320336759), (8327, 0.6324555320336759)]
#                name      developer  positive  negative              owners  \
# 5471           Maui    Kokua Games       152       177  100,000 .. 200,000
# 8129  One Ping Only  Triconn Games       168        17    20,000 .. 50,000
#
#       average_playtime  median_playtime  price languages  \
# 5471              16.0             31.0    0.0   English
# 8129               0.0              0.0    0.0   English
#
#                                                genre  \
# 5471  Action, Adventure, Casual, Free to Play, Indie
# 8129  Action, Adventure, Casual, Free to Play, Indie
#
#                                    detailed_description  Ratings Is_Free  \
# 5471  the gods have trap your sister prove yourself ...      -25    Free
# 8129  one ping only be an student build action adven...      151    Free
#
#      English  download                                            feature
# 5471     Yes    200000  action adventure casual free to play indie mau...
# 8129     Yes     50000  action adventure casual free to play indie one...

# %%
feature_rec("PLAYERUNKNOWN'S BATTLEGROUNDS").head(2)
# Out:
# [(8068, 0.5892556509887895), (1209, 0.5345224838248487), (3103, 0.4999999999999999), (8150, 0.4999999999999999), (6583, 0.49029033784546006), (2848, 0.472455591261534), (1099, 0.4714045207910316), (1711, 0.4714045207910316), (2555, 0.4714045207910316), (5049, 0.4714045207910316)]
#                       name            developer  positive  negative  \
# 8068  RUSSIA BATTLEGROUNDS            Agafonoff       789       299
# 1209                  DayZ  Bohemia Interactive    118435     77169
#
#                       owners  average_playtime  median_playtime  price  \
# 8068      100,000 .. 200,000               0.0              0.0   0.99
# 1209  2,000,000 .. 5,000,000            7235.0           2798.0  44.99
#
#                                               languages  \
# 8068  English, French, Italian, German, Spanish - Sp...
# 1209  English, French, Italian, German, Spanish - Sp...
#
#                                                   genre  \
# 8068  Action, Adventure, Indie, Massively Multiplaye...
# 1209           Action, Adventure, Massively Multiplayer
#
#                                    detailed_description  Ratings Is_Free  \
# 8068  russia battlegrounds be a multiplayer battle r...      490    Paid
# 1209  the post soviet country of chernarus be strike...    41266    Paid
#
#      English  download                                            feature
# 8068     Yes    200000  action adventure indie massively multiplayer r...
# 1209     Yes   5000000  action adventure massively multiplayer dayz bo...

# %%
feature_rec('Warframe').head(2)
# Out:
# [(428, 0.5477225575051662), (752, 0.5477225575051662), (3360, 0.5477225575051662), (8522, 0.5477225575051662), (1007, 0.545544725589981), (2886, 0.5163977794943223), (19, 0.5000000000000001), (22, 0.5000000000000001), (362, 0.5000000000000001), (678, 0.5000000000000001)]
#                 name         developer  positive  negative  \
# 428      Dark Sector  Digital Extremes       337        96
# 752  The Darkness II  Digital Extremes     11992      1234
#
#                      owners  average_playtime  median_playtime  price  \
# 428       50,000 .. 100,000               0.0              0.0   9.99
# 752  1,000,000 .. 2,000,000             191.0            214.0   5.99
#
#                                              languages   genre  \
# 428                                    English, French  Action
# 752  English, French, German, Italian, Japanese, Sp...  Action
#
#                                   detailed_description  Ratings Is_Free  \
# 428  dark sector thrust players into the role of ha...      241    Paid
# 752  inspire by the popular comic book series produ...    10758    Paid
#
#     English  download                                  feature
# 428     Yes    100000      action dark sector digital extremes
# 752     Yes   2000000  action the darkness ii digital extremes

# %% [markdown]
# ## Evaluation Metrics

# %% [markdown]
# To evaluate the recommender system:
#
# 1. Compare NMI/similarity scores between recommendations.
# 2. To conduct survey of 30 person to rate (1-5) 5 recommendations with picture and description between 2 recommenders, then compare RMSE.

# %%
np.arrays_equal(tfidf_matrix[1673].todense(), tfidf_matrix[4405].todense())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-820d832a9fb4> in <module>
# ----> 1 np.arrays_equal(tfidf_matrix[1673].todense(), tfidf_matrix[4405].todense())
#
# /usr/local/lib/python3.7/dist-packages/numpy/__init__.py in __getattr__(attr)
#     312
#     313             raise AttributeError("module {!r} has no attribute "
# --> 314                                  "{!r}".format(__name__, attr))
#     315
#     316         def __dir__():
#
# AttributeError: module 'numpy' has no attribute 'arrays_equal'

# %%
x = np.array(tfidf_matrix[1673])

# %%
y = np.array(tfidf_matrix[4405])

# %%
x!= y
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   """Entry point for launching an IPython kernel.
# True

# %%
from sklearn.metrics.cluster import normalized_mutual_info_score
normalized_mutual_info_score(x, y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-09cc05beea6a> in <module>
#       1 from sklearn.metrics.cluster import normalized_mutual_info_score
# ----> 2 normalized_mutual_info_score(x, y)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/cluster/_supervised.py in normalized_mutual_info_score(labels_true, labels_pred, average_method)
#    1018       0.0
#    1019     """
# -> 1020     labels_true, labels_pred = check_clusterings(labels_true, labels_pred)
#    1021     classes = np.unique(labels_true)
#    1022     clusters = np.unique(labels_pred)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/cluster/_supervised.py in check_clusterings(labels_true, labels_pred)
#      44         ensure_2d=False,
#      45         ensure_min_samples=0,
# ---> 46         dtype=None,
#      47     )
#      48
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     798
#     799         if force_all_finite:
# --> 800             _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     801
#     802     if ensure_min_samples > 0:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     119     # for object dtype data, we only check for NaNs (GH-13254)
#     120     elif X.dtype == np.dtype("object") and not allow_nan:
# --> 121         if _object_dtype_isnan(X).any():
#     122             raise ValueError("Input contains NaN")
#     123
#
# AttributeError: 'bool' object has no attribute 'any'

# %%
tfidf_tokens = tfidf.get_feature_names_out()
df_tfidfvect = pd.DataFrame(data = tfidf_matrix.toarray(),index = [df.loc[851,'name'],df.loc[2303,'name']],columns = tfidf_tokens)
print("\nTD-IDF Vectorizer\n")
print(df_tfidfvect)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-35607985b45b> in <module>
#       1 tfidf_tokens = tfidf.get_feature_names_out()
# ----> 2 df_tfidfvect = pd.DataFrame(data = tfidf_matrix.toarray(),index = [df.loc[851,'name'],df.loc[2303,'name']],columns = tfidf_tokens)
#       3 print("\nTD-IDF Vectorizer\n")
#       4 print(df_tfidfvect)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     676                     dtype=dtype,
#     677                     copy=copy,
# --> 678                     typ=manager,
#     679                 )
#     680
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     322     )
#     323
# --> 324     _check_values_indices_shape_match(values, index, columns)
#     325
#     326     if typ == "array":
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in _check_values_indices_shape_match(values, index, columns)
#     391         passed = values.shape
#     392         implied = (len(index), len(columns))
# --> 393         raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#     394
#     395
#
# ValueError: Shape of passed values is (3658, 40105), indices imply (2, 40105)
