# %% [markdown]
# # MCSD6215 Master Project
# Name: Tan Boon Chu
#
# Matrics No.: MCS211006
#
# Project Title: EDA and Recommender System for Steam Online Gaming Platform

# %% [markdown]
# ## Data Import

# %%
import pandas as pd
import numpy as np

# %%
# Import PyDrive and associated libraries
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client
# This only needs to be done once per notebook
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# Import first dataset

# %%
# Download a file based on its file ID.

file_id = '1OUlfevxyjoVxF3qSgzN1o7IBcGHN5S76'
downloaded = drive.CreateFile({'id': file_id})

# Save file in Colab memory
downloaded.GetContentFile('steamspy_data.csv')  

# Read Data file
df1 = pd.read_csv('steamspy_data.csv')

# %% [markdown]
# Import second dataset with descriptions

# %%
file_id = '1pVwlu6jdg2N2ke0jju9xng3V1SD_u8Ln' 
downloaded = drive.CreateFile({'id': file_id})

downloaded.GetContentFile('steam_app_data.csv')  
# Read Data file
df2 = pd.read_csv('steam_app_data.csv')

# %%
# Extract only the description from 2nd dataset
df2 = df2[['name','detailed_description']]

# %% [markdown]
# ## Data Integration

# %%
# Data Integration
df = pd.merge(df1, df2, on='name', how='outer')
df = pd.DataFrame(df)

# %%
# print out number of rows and columns
print('Rows:', df.shape[0])
print('Columns:', df.shape[1])

# View first 5 rows
df.head()
# Out:
# Rows: 30083
# Columns: 21
#    appid                       name         developer publisher  score_rank  \
# 0   10.0             Counter-Strike             Valve     Valve         NaN
# 1   20.0      Team Fortress Classic             Valve     Valve         NaN
# 2   30.0              Day of Defeat             Valve     Valve         NaN
# 3   40.0         Deathmatch Classic             Valve     Valve         NaN
# 4   50.0  Half-Life: Opposing Force  Gearbox Software     Valve         NaN
#
#    positive  negative  userscore                    owners  average_forever  \
# 0  124534.0    3339.0        0.0  10,000,000 .. 20,000,000          17612.0
# 1    3318.0     633.0        0.0   5,000,000 .. 10,000,000            277.0
# 2    3416.0     398.0        0.0   5,000,000 .. 10,000,000            187.0
# 3    1273.0     267.0        0.0   5,000,000 .. 10,000,000            258.0
# 4    5250.0     288.0        0.0   5,000,000 .. 10,000,000            624.0
#
#    ...  median_forever  median_2weeks  price  initialprice  discount  \
# 0  ...           317.0           26.0  999.0         999.0       0.0
# 1  ...            62.0           15.0  499.0         499.0       0.0
# 2  ...            34.0            0.0  499.0         499.0       0.0
# 3  ...           184.0            0.0  499.0         499.0       0.0
# 4  ...           415.0            0.0  499.0         499.0       0.0
#
#                                            languages   genre      ccu  \
# 0  English, French, German, Italian, Spanish - Sp...  Action  14923.0
# 1  English, French, German, Italian, Spanish - Sp...  Action     87.0
# 2  English, French, German, Italian, Spanish - Spain  Action    130.0
# 3  English, French, German, Italian, Spanish - Sp...  Action      4.0
# 4                    English, French, German, Korean  Action     71.0
#
#                                                 tags  \
# 0  {'Action': 2681, 'FPS': 2048, 'Multiplayer': 1...
# 1  {'Action': 208, 'FPS': 188, 'Multiplayer': 172...
# 2  {'FPS': 138, 'World War II': 122, 'Multiplayer...
# 3  {'Action': 85, 'FPS': 71, 'Multiplayer': 58, '...
# 4  {'FPS': 235, 'Action': 211, 'Sci-fi': 166, 'Si...
#
#                                 detailed_description
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Data Cleaning

# %%
df.isnull().sum()
# Out:
# appid                     622
# name                        5
# developer                 824
# publisher                 909
# score_rank              30025
# positive                  622
# negative                  622
# userscore                 622
# owners                    622
# average_forever           622
# average_2weeks            622
# median_forever            622
# median_2weeks             622
# price                     653
# initialprice              646
# discount                  646
# languages                 718
# genre                     776
# ccu                       622
# tags                      622
# detailed_description      882
# dtype: int64

# %%
df.drop(['score_rank', 'userscore', 'publisher', 'initialprice', 'discount', 
         'average_2weeks', 'median_2weeks', 'ccu', 'tags'], axis=1, inplace=True)
df.head()
# Out:
#    appid                       name         developer  positive  negative  \
# 0   10.0             Counter-Strike             Valve  124534.0    3339.0
# 1   20.0      Team Fortress Classic             Valve    3318.0     633.0
# 2   30.0              Day of Defeat             Valve    3416.0     398.0
# 3   40.0         Deathmatch Classic             Valve    1273.0     267.0
# 4   50.0  Half-Life: Opposing Force  Gearbox Software    5250.0     288.0
#
#                      owners  average_forever  median_forever  price  \
# 0  10,000,000 .. 20,000,000          17612.0           317.0  999.0
# 1   5,000,000 .. 10,000,000            277.0            62.0  499.0
# 2   5,000,000 .. 10,000,000            187.0            34.0  499.0
# 3   5,000,000 .. 10,000,000            258.0           184.0  499.0
# 4   5,000,000 .. 10,000,000            624.0           415.0  499.0
#
#                                            languages   genre  \
# 0  English, French, German, Italian, Spanish - Sp...  Action
# 1  English, French, German, Italian, Spanish - Sp...  Action
# 2  English, French, German, Italian, Spanish - Spain  Action
# 3  English, French, German, Italian, Spanish - Sp...  Action
# 4                    English, French, German, Korean  Action
#
#                                 detailed_description
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...

# %%
df['price'] = df['price'].fillna(df['price'].mean())
df['languages'] = df['languages'].fillna('English')
df[['developer','genre']] = df[['developer','genre']].fillna('Other')
df.isnull().sum()
# Out:
# appid                   622
# name                      5
# developer                 0
# positive                622
# negative                622
# owners                  622
# average_forever         622
# median_forever          622
# price                     0
# languages                 0
# genre                     0
# detailed_description    882
# dtype: int64

# %%
# Drop row on appid, name, and detailed description having null values
df.dropna(inplace = True)
df.isnull().sum()
# Out:
# appid                   0
# name                    0
# developer               0
# positive                0
# negative                0
# owners                  0
# average_forever         0
# median_forever          0
# price                   0
# languages               0
# genre                   0
# detailed_description    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 20

# %%
df.duplicated(subset='name').sum()
# Out:
# 199

# %%
df[df.duplicated(subset='name',keep=False)]
# Out:
#            appid                     name  \
# 114       1300.0  SiN Episodes: Emergence
# 115       1300.0  SiN Episodes: Emergence
# 116       1300.0  SiN Episodes: Emergence
# 117       1309.0  SiN Episodes: Emergence
# 118       1309.0  SiN Episodes: Emergence
# ...          ...                      ...
# 25991   998820.0                   Cortex
# 26932   942050.0                     2048
# 26933   942050.0                     2048
# 26934  1026330.0                     2048
# 26935  1026330.0                     2048
#
#                                                developer  positive  negative  \
# 114                                 Ritual Entertainment     468.0      61.0
# 115                                 Ritual Entertainment     468.0      61.0
# 116                                 Ritual Entertainment     468.0      61.0
# 117                                 Ritual Entertainment     322.0      45.0
# 118                                 Ritual Entertainment     322.0      45.0
# ...                                                  ...       ...       ...
# 25991                                         Milan Toth       5.0       0.0
# 26932  Lucas Alexander Visual Arts, Nicolai Clemmense...       4.0       0.0
# 26933  Lucas Alexander Visual Arts, Nicolai Clemmense...       4.0       0.0
# 26934                                       Dexion Games       0.0       1.0
# 26935                                       Dexion Games       0.0       1.0
#
#                    owners  average_forever  median_forever  price  \
# 114    100,000 .. 200,000              0.0             0.0  999.0
# 115    100,000 .. 200,000              0.0             0.0  999.0
# 116    100,000 .. 200,000              0.0             0.0  999.0
# 117    200,000 .. 500,000              0.0             0.0  999.0
# 118    200,000 .. 500,000              0.0             0.0  999.0
# ...                   ...              ...             ...    ...
# 25991         0 .. 20,000              0.0             0.0    0.0
# 26932         0 .. 20,000              0.0             0.0  499.0
# 26933         0 .. 20,000              0.0             0.0  499.0
# 26934         0 .. 20,000              0.0             0.0   99.0
# 26935         0 .. 20,000              0.0             0.0   99.0
#
#                       languages                      genre  \
# 114    English, Russian, French                     Action
# 115    English, Russian, French                     Action
# 116    English, Russian, French                     Action
# 117    English, Russian, French                     Action
# 118    English, Russian, French                     Action
# ...                         ...                        ...
# 25991                   English                     Action
# 26932                   English    Casual, Indie, Strategy
# 26933                   English    Casual, Indie, Strategy
# 26934                   English  Casual, Indie, Simulation
# 26935                   English  Casual, Indie, Simulation
#
#                                     detailed_description
# 114    You are John Blade, commander of HardCorps, an...
# 115    You are John Blade, commander of HardCorps, an...
# 116    You are John Blade, commander of HardCorps, an...
# 117    You are John Blade, commander of HardCorps, an...
# 118    You are John Blade, commander of HardCorps, an...
# ...                                                  ...
# 25991  &quot;You are a thought. A thought to be born....
# 26932  2048 is a classic puzzle with a simple goal; r...
# 26933  2048 is played on a 4×4 grid, with numbered ti...
# 26934  2048 is a classic puzzle with a simple goal; r...
# 26935  2048 is played on a 4×4 grid, with numbered ti...
#
# [261 rows x 12 columns]

# %%
df.drop_duplicates(subset='name', keep="first", inplace=True)

# %%
df.duplicated(subset='name').sum()
# Out:
# 0

# %%
# Data type
df.dtypes
# Out:
# appid                   float64
# name                     object
# developer                object
# positive                float64
# negative                float64
# owners                   object
# average_forever         float64
# median_forever          float64
# price                   float64
# languages                object
# genre                    object
# detailed_description     object
# dtype: object

# %%
df = df.astype({'appid':int, 'positive':int,'negative':int})

# %% [markdown]
# ## Feature Engineering

# %%
df['Ratings'] = df.positive - df.negative
df['Is_Free'] = np.where(df['price']==0, 'Free', 'Paid')
df['English'] = np.where(df['languages'].str.contains("English"), 'Yes', 'No')

# %%
df['download'] = df['owners'].str.replace(',', '').str.split(' .. ')
df['download'] = df['download'].apply(lambda x: int(x[1]))

# %%
df = df.rename({
    'average_forever': 'average_playtime',
    'median_forever': 'median_playtime'
}, axis=1)

# %%
df.loc[df['price'] > 0, 'price'] /= 100
df['appid'] = df.appid // 10

# %%
print('Rows:',df.shape[0])
print('Columns:',df.shape[1])
df.head()
# Out:
# Rows: 28375
# Columns: 16
#    appid                       name         developer  positive  negative  \
# 0      1             Counter-Strike             Valve    124534      3339
# 1      2      Team Fortress Classic             Valve      3318       633
# 2      3              Day of Defeat             Valve      3416       398
# 3      4         Deathmatch Classic             Valve      1273       267
# 4      5  Half-Life: Opposing Force  Gearbox Software      5250       288
#
#                      owners  average_playtime  median_playtime  price  \
# 0  10,000,000 .. 20,000,000           17612.0            317.0   9.99
# 1   5,000,000 .. 10,000,000             277.0             62.0   4.99
# 2   5,000,000 .. 10,000,000             187.0             34.0   4.99
# 3   5,000,000 .. 10,000,000             258.0            184.0   4.99
# 4   5,000,000 .. 10,000,000             624.0            415.0   4.99
#
#                                            languages   genre  \
# 0  English, French, German, Italian, Spanish - Sp...  Action
# 1  English, French, German, Italian, Spanish - Sp...  Action
# 2  English, French, German, Italian, Spanish - Spain  Action
# 3  English, French, German, Italian, Spanish - Sp...  Action
# 4                    English, French, German, Korean  Action
#
#                                 detailed_description  Ratings Is_Free English  \
# 0  Play the world's number 1 online action game. ...   121195    Paid     Yes
# 1  One of the most popular online action games of...     2685    Paid     Yes
# 2  Enlist in an intense brand of Axis vs. Allied ...     3018    Paid     Yes
# 3  Enjoy fast-paced multiplayer gaming with Death...     1006    Paid     Yes
# 4  Return to the Black Mesa Research Facility as ...     4962    Paid     Yes
#
#    download
# 0  20000000
# 1  10000000
# 2  10000000
# 3  10000000
# 4  10000000

# %% [markdown]
# ## Data Export

# %%
from google.colab import files

df.to_csv('steam_clean_data.csv',index=False)
files.download('steam_clean_data.csv')
